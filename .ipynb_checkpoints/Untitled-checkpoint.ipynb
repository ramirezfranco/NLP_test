# %%
import nltk

# %%
import util
# Out:
# C:\Users\jesus\Anaconda3\lib\site-packages\nltk\tag\stanford.py:183: DeprecationWarning:
# The StanfordTokenizer will be deprecated in version 3.2.5.
# Please use nltk.tag.corenlp.CoreNLPPOSTagger or nltk.tag.corenlp.CoreNLPNERTagger instead.
#   super(StanfordNERTagger, self).__init__(*args, **kwargs)

# %%
'%USERPROFILE%/OneDrive/Documentos/GitHub/NLP_test'
'C:/Users/jesus/OneDrive/Documentos/GitHub/NLP_test'
# Out:
# 'C:/Users/jesus/OneDrive/Documentos/GitHub/NLP_test'

# %%
def read_corpora(corpus_root, fields, encoding):
    corpus_root = corpus_root
    fields = fields
    encoding = encoding
    wordlists = PlaintextCorpusReader(corpus_root, fields, encoding)
    print('This are the corpora available:')
    for field in wordllists:
        print(field)

# %%
def entity_tagger(text):

# %%
from nltk.corpus import PlaintextCorpusReader
corpus_root = 'C:/Users/jesus/OneDrive/Documentos/GitHub/NLP_test'

# %%
wordlists = PlaintextCorpusReader(corpus_root, '.*',encoding='ANSI')

# %%
wordlists.fileids()
# Out:
# ['.ipynb_checkpoints/Untitled-checkpoint.ipynb',
#  'Untitled.ipynb',
#  'results.txt',
#  'results1.txt',
#  'stanford-ner-2018-02-27/LICENSE.txt',
#  'stanford-ner-2018-02-27/NERDemo.java',
#  'stanford-ner-2018-02-27/README.txt',
#  'stanford-ner-2018-02-27/build.xml',
#  'stanford-ner-2018-02-27/classifiers/english.all.3class.distsim.crf.ser.gz',
#  'stanford-ner-2018-02-27/classifiers/english.all.3class.distsim.prop',
#  'stanford-ner-2018-02-27/classifiers/english.conll.4class.distsim.crf.ser.gz',
#  'stanford-ner-2018-02-27/classifiers/english.conll.4class.distsim.prop',
#  'stanford-ner-2018-02-27/classifiers/english.muc.7class.distsim.crf.ser.gz',
#  'stanford-ner-2018-02-27/classifiers/english.muc.7class.distsim.prop',
#  'stanford-ner-2018-02-27/classifiers/example.serialized.ncc.ncc.ser.gz',
#  'stanford-ner-2018-02-27/classifiers/example.serialized.ncc.prop',
#  'stanford-ner-2018-02-27/lib/joda-time.jar',
#  'stanford-ner-2018-02-27/lib/jollyday-0.4.9.jar',
# ...

# %%
wordlists.words('results1.txt')
# Out:
# ['€\x03}', 'q', '\x00(', 'XA', '\x00\x00\x00', 'https', ...]

# %%
type(wordlists.raw())
# Out:
# str

# %%
seq = wordlists.words('results1.txt')

# %%
results1_str = ' '.join(seq)

# %%
results1_str
# Out:
# '€\x03} q \x00( XA \x00\x00\x00 https :// www . hks . harvard . edu / educational - programs / masters - programsq \x01 X °\x04\x00\x00 The masterâ €™ s programs at Harvard Kennedy School will inspire and prepare you to make a difference in the world by equipping you with the skills you need to improve public policy , pursue powerful ideas , and advance your capacity to lead . Harvard Kennedy School is the place to transform your desire to do good in the world into real , life - changing action . Explore . Learn more . Ask what you can do . The two - year MPP Program is rigorous training that prepares you to understand complex problems and craft concrete solutions . The two - year MPA / ID Program combines rigorous training in economics and quantitative methods with an emphasis on policy and practice . The two - year MPA Program teaches the skills you need to be an even more effective leader in solving public problems . The one - year MC / MPA Program elevates the abilities of establ
# ...

# %%
model_path = 'C:/Users/jesus/OneDrive/Documentos/GitHub/NLP_test/stanford-ner-2018-02-27/classifiers/english.muc.7class.distsim.crf.ser.gz'
jar_path = 'C:/Users/jesus/OneDrive/Documentos/GitHub/NLP_test/stanford-ner-2018-02-27/stanford-ner.jar'

# %%
from nltk.tag import StanfordNERTagger
from nltk.tokenize import word_tokenize

# %%
java_path = 'C:/Program Files/Java/jdk-11/bin/java.exe'

# %%
import os
os.environ['JAVAHOME'] = java_path

# %%
st = StanfordNERTagger(model_path, jar_path)

text = 'While in France, Christine Lagarde discussed short-term stimulus efforts in a recent interview with the Wall Street Journal, she said that currencies and money are secured.'

tokenized_text = word_tokenize(text)
classified_text = st.tag(tokenized_text)

print(classified_text)
# Out:
# C:\Users\jesus\Anaconda3\lib\site-packages\nltk\tag\stanford.py:183: DeprecationWarning:
# The StanfordTokenizer will be deprecated in version 3.2.5.
# Please use nltk.tag.corenlp.CoreNLPPOSTagger or nltk.tag.corenlp.CoreNLPNERTagger instead.
#   super(StanfordNERTagger, self).__init__(*args, **kwargs)
# [('While', 'O'), ('in', 'O'), ('France', 'LOCATION'), (',', 'O'), ('Christine', 'PERSON'), ('Lagarde', 'PERSON'), ('discussed', 'O'), ('short-term', 'O'), ('stimulus', 'O'), ('efforts', 'O'), ('in', 'O'), ('a', 'O'), ('recent', 'O'), ('interview', 'O'), ('with', 'O'), ('the', 'O'), ('Wall', 'O'), ('Street', 'O'), ('Journal', 'O'), (',', 'O'), ('she', 'O'), ('said', 'O'), ('that', 'O'), ('currencies', 'O'), ('and', 'O'), ('money', 'O'), ('are', 'O'), ('secured', 'O'), ('.', 'O')]

# %%
i= "He was born on October 15, 1931 at Dhanushkothi in the temple town Rameshwaram in Tamil Nadu, I was born poor, with no enough dolars to live."

words = word_tokenize(i)
namedEnt = st.tag(words)

print (namedEnt)
# Out:
# [('He', 'O'), ('was', 'O'), ('born', 'O'), ('on', 'O'), ('October', 'DATE'), ('15', 'DATE'), (',', 'DATE'), ('1931', 'DATE'), ('at', 'O'), ('Dhanushkothi', 'O'), ('in', 'O'), ('the', 'O'), ('temple', 'O'), ('town', 'O'), ('Rameshwaram', 'O'), ('in', 'O'), ('Tamil', 'ORGANIZATION'), ('Nadu', 'ORGANIZATION'), (',', 'O'), ('I', 'O'), ('was', 'O'), ('born', 'O'), ('poor', 'O'), (',', 'O'), ('with', 'O'), ('no', 'O'), ('enough', 'O'), ('dolars', 'O'), ('to', 'O'), ('live', 'O'), ('.', 'O')]

# %%
results1_tag = st.tag(word_tokenize(results1_str))

# %%
types = []
for tup in results1_tag:
    if tup[1]!= 'O':
        types.append(tup[1])

# %%
set(types)
# Out:
# {'DATE', 'LOCATION', 'MONEY', 'ORGANIZATION', 'PERCENT', 'PERSON', 'TIME'}

# %%
count = 0
for tup in results1_tag:
    if tup[1] == 'MONEY':
        count += 1
        print(tup)
print('there are', count, 'tuples tagged as money')
# Out:
# ('$', 'MONEY')
# ('X', 'MONEY')
# ('3', 'MONEY')
# ('million', 'MONEY')
# ('$', 'MONEY')
# ('16', 'MONEY')
# ('million', 'MONEY')
# ('tens', 'MONEY')
# ('of', 'MONEY')
# ('millions', 'MONEY')
# ('of', 'MONEY')
# ('dollars', 'MONEY')
# ('$', 'MONEY')
# ('135', 'MONEY')
# ('million', 'MONEY')
# ('$', 'MONEY')
# ('22', 'MONEY')
# ('million', 'MONEY')
# ('$', 'MONEY')
# ('50', 'MONEY')
# ('million', 'MONEY')
# ('$', 'MONEY')
# ('100', 'MONEY')
# ('million', 'MONEY')
# ('$', 'MONEY')
# ('30', 'MONEY')
# ('million', 'MONEY')
# ('$', 'MONEY')
# ('12', 'MONEY')
# ('million', 'MONEY')
# ('$', 'MONEY')
# ('20', 'MONEY')
# ('million', 'MONEY')
# ('$', 'MONEY')
# ('38', 'MONEY')
# ('billion', 'MONEY')
# ('$', 'MONEY')
# ('30', 'MONEY')
# ('billion', 'MONEY')
# ('$', 'MONEY')
# ('169', 'MONEY')
# ('million', 'MONEY')
# ('$', 'MONEY')
# ('2', 'MONEY')
# ('billion', 'MONEY')
# ('$', 'MONEY')
# ('2', 'MONEY')
# ('$', 'MONEY')
# ('200', 'MONEY')
# ('billion', 'MONEY')
# ('$', 'MONEY')
# ...

# %%
for sentence in nltk.sent_tokenize(results1_str)[:10]:
    print(st.tag(word_tokenize(sentence)))
# Out:
# [('€\x03', 'O'), ('}', 'O'), ('q', 'O'), ('\x00', 'O'), ('(', 'O'), ('XA', 'O'), ('\x00\x00\x00', 'O'), ('https', 'O'), (':', 'O'), ('', 'O'), ('www', 'O'), ('.', 'O')]
# [('hks', 'O'), ('.', 'O')]
# [('harvard', 'O'), ('.', 'O')]
# ...

# %%
type(util.tagger('oh my god what i am going to do'))
# Out:
# list

# %%
util.tag_sentence('While in France, Christine Lagarde discussed short-term stimulus efforts in a recent interview', 'MONEY')
# Out:
# False

# %%
util.tagger('oh my god what i am going to do')
# Out:
# [('oh', 'O'),
#  ('my', 'O'),
#  ('god', 'O'),
#  ('what', 'O'),
#  ('i', 'O'),
#  ('am', 'O'),
#  ('going', 'O'),
#  ('to', 'O'),
#  ('do', 'O')]

# %%
corpus_root = 'C:/Users/jesus/OneDrive/Documentos/GitHub/NLP_test/data'

# %%
util.read_corpora(corpus_root, '.*', 'ANSI')
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-12-2b13655d164c> in <module>()
# ----> 1 util.read_corpora(corpus_root, '.*', 'ANSI')
#
# ~\OneDrive\Documentos\GitHub\NLP_test\util.py in read_corpora(corpus_root, files, encoding)
#      23 def read_corpora(corpus_root, files, encoding):
#      24 	'''
# ---> 25         # Creates strings from txts located in the copus root
#      26         Inputs:
#      27                 corpus_root (string):
#
# UnboundLocalError: local variable 'fields' referenced before assignment
